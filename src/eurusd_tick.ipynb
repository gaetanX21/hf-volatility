# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

# %%
df = pd.read_csv('../datasets/EURUSD tick dec 2023/tick.csv', header=None)
df.columns = ['timestamp', 'bid', 'ask', 'volume']
df['timestamp'] = pd.to_datetime(df['timestamp'], format='%Y%m%d %H%M%S%f')
df['date'] = df['timestamp'].dt.date
df['time'] = df['timestamp'].dt.time

# %% [markdown]
# Facts:
# - Market closed on Saturday...
#
# - ![image.png](attachment:image.png)
#
# - comprendre les horaires du forex EUR/USD !?

# %%
n=101780
df['timestamp'].iloc[n:n+20]
# Out:
# 101780   2023-12-01 16:59:08.938
# 101781   2023-12-01 16:59:09.292
# 101782   2023-12-01 16:59:17.943
# 101783   2023-12-01 16:59:19.149
# 101784   2023-12-01 16:59:19.804
# 101785   2023-12-01 16:59:20.108
# 101786   2023-12-01 16:59:20.310
# 101787   2023-12-01 16:59:20.864
# 101788   2023-12-01 16:59:29.615
# 101789   2023-12-01 16:59:30.674
# 101790   2023-12-01 16:59:37.554
# 101791   2023-12-01 16:59:44.376
# 101792   2023-12-01 16:59:44.479
# 101793   2023-12-03 17:00:00.304
# 101794   2023-12-03 17:00:00.506
# 101795   2023-12-03 17:00:01.311
# 101796   2023-12-03 17:00:04.470
# 101797   2023-12-03 17:00:05.825
# 101798   2023-12-03 17:00:06.478
# 101799   2023-12-03 17:00:31.098
# Name: timestamp, dtype: datetime64[ns]
